# %%
import torch
from IPython.display import Image

# %%
import cv2
import subprocess
import ultralytics

# %%
def run_model(source):
    cmd ="python yolov5-master/detect.py --source " +source + " --weights last.pt"
    subprocess.run(cmd,shell="True",capture_output="True")

# %%
run_model("face-mask-today-main1-200423.jpg")

# %%
# !python3 /content/yolov5/detect.py --source /content/drive/MyDrive/FaceMaskYOLOv5/hcm-city-fines-people-without-face-masks.jpg --weights /content/yolov5/runs/train/exp/weights/last.pt
# Out:
# detect: weights=['/content/yolov5/runs/train/exp/weights/last.pt'], source=/content/drive/MyDrive/FaceMaskYOLOv5/hcm-city-fines-people-without-face-masks.jpg, data=yolov5/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-178-ga199480 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7018216 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/drive/MyDrive/FaceMaskYOLOv5/hcm-city-fines-people-without-face-masks.jpg: 352x640 4 1s, 1 2, 61.0ms
# Speed: 0.6ms pre-process, 61.0ms inference, 1.9ms NMS per image at shape (1, 3, 640, 640)
# ...

# %% [markdown]
# #Save models
